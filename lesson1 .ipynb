# %%
import csv

# %%
streets = {}

# %%
with open('data-398-2019-12-31.csv', 'r', encoding="cp1251") as f:
    reader = csv.DictReader(f, delimiter=";")
    for row in reader:
        if row['Street'] in streets:
            streets[row['Street']] += 1
        else:
            streets[row['Street']] = 1
streets
# Out:
# {'3-й Дербеневский переулок': 8,
#  'набережная Тараса Шевченко': 8,
#  '3-я Черепковская улица': 20,
#  'улица Сущёвский Вал': 84,
#  'Дубнинская улица': 112,
#  'улица 800-летия Москвы': 52,
#  'Дмитровское шоссе': 284,
#  'Локомотивный проезд': 28,
#  'Большая Академическая улица': 96,
#  'улица Зои и Александра Космодемьянских': 56,
#  'Ангарская улица': 64,
#  'Коровинское шоссе': 92,
#  'Клязьминская улица': 48,
#  'улица Линии Октябрьской Железной Дороги': 24,
#  'Старопетровский проезд': 40,
#  'улица Клары Цеткин': 20,
#  'Михалковская улица': 56,
#  'Онежская улица': 44,
#  'Петрозаводская улица': 36,
#  'Беломорская улица': 36,
#  'Смольная улица': 68,
#  'Фестивальная улица': 100,
#  'Бескудниковский бульвар': 88,
#  'Коптевский бульвар': 16,
#  'Коптевская улица': 40,
#  'Кронштадтский бульвар': 80,
#  'Нарвская улица': 24,
#  '3-й Лихачёвский переулок': 4,
#  '4-й Лихачёвский переулок': 8,
#  'Автомоторная улица': 24,
#  '4-й Новомихалковский проезд': 16,
#  'Митинская улица': 56,
#  'улица Дыбенко': 36,
#  'Зеленоградская улица': 48,
#  'улица Академика Курчатова': 20,
#  'Сосновая улица': 12,
#  'Пехотная улица': 8,
#  '1-й Волоколамский проезд': 16,
#  'улица Усиевича': 16,
#  'Планетная улица': 28,
#  'Петровско-Разумовская аллея': 24,
#  'Часовая улица': 16,
#  '2-й Пехотный переулок': 8,
#  'Авангардная улица': 24,
#  'Флотская улица': 52,
#  'Солнечногорская улица': 24,
#  'Сенежская улица': 8,
#  'улица Прянишникова': 20,
#  'Тимирязевская улица': 84,
#  'улица Вучетича': 24,
#  '2-я Хуторская улица': 16,
#  'Петровско-Разумовский проезд': 32,
#  'Ижорская улица': 24,
#  'улица Бусиновская Горка': 16,
#  'Краснополянская улица': 20,
#  'улица Лавочкина': 20,
#  'Бутырская улица': 56,
#  'улица Бутырский Вал': 32,
#  'Новослободская улица': 32,
#  'Волоколамское шоссе': 184,
#  'Херсонская улица': 40,
#  'Ленинградский проспект': 148,
#  'Ботаническая улица': 56,
#  'улица Академика Королёва': 68,
#  'Новомосковская улица': 28,
#  'Звёздный бульвар': 20,
#  '6-й Новоостанкинский проезд': 4,
#  'улица Цандера': 8,
#  'улица Кондратюка': 4,
#  'проспект Мира': 296,
#  'Сусоколовское шоссе': 8,
#  'улица Героев Панфиловцев': 144,
#  'Сходненская улица': 44,
#  'Лодочная улица': 44,
#  'улица Свободы': 140,
#  'Авиационная улица': 48,
#  'улица Маршала Федоренко': 20,
#  'улица Лужники': 28,
#  'Лужнецкая набережная': 12,
#  'Лужнецкий проезд': 8,
#  'Большая Пироговская улица': 48,
#  'улица Плющиха': 28,
#  'улица Хамовнический Вал': 24,
#  'Смоленская-Сенная площадь': 12,
#  'Новинский бульвар': 16,
#  'улица Красная Пресня': 36,
#  'улица 1905 Года': 16,
#  'Хорошёвское шоссе': 100,
#  'Кудринская площадь': 8,
#  'улица Еланского': 4,
#  'Станционная улица': 20,
#  'Красностуденческий проезд': 20,
#  'Смоленский бульвар': 16,
#  'улица Берзарина': 44,
#  'улица Расплетина': 20,
#  'улица Маршала Бирюзова': 64,
#  'улица Василия Петушкова': 44,
#  'Светлогорский проезд': 16,
#  'Гостиничная улица': 4,
#  'Башиловская улица': 32,
#  'улица Расковой': 16,
#  '5-я улица Ямского Поля': 8,
#  '1-я улица Ямского Поля': 8,
#  'улица Нижняя Масловка': 32,
#  '3-й Нижнелихоборский проезд': 16,
#  'улица Исаковского': 52,
#  'улица Маршала Катукова': 64,
#  'Рублёвское шоссе': 164,
#  'улица Кулакова': 68,
#  '2-я Квесисская улица': 20,
#  'Мякининский проезд': 8,
#  '2-й Крестовский переулок': 4,
#  'Рижская площадь': 12,
#  '4-й Вятский переулок': 20,
#  'Старый Петровско-Разумовский проезд': 16,
#  'Ленинградское шоссе': 224,
#  'бульвар Яна Райниса': 68,
#  'Химкинский бульвар': 24,
#  'улица Костякова': 32,
#  'улица Куусинена': 44,
#  'улица Маршала Тухачевского': 40,
#  'улица Народного Ополчения': 100,
#  'улица Саляма Адиля': 12,
#  'Карамышевская набережная': 36,
#  'улица Мнёвники': 36,
#  'проспект Маршала Жукова': 84,
#  'Таманская улица': 52,
#  'Карамышевский проезд': 8,
#  'улица Константина Царёва': 32,
#  'Звенигородское шоссе': 40,
#  '1-й Новоподмосковный переулок': 8,
#  'Проспект Маршала Жукова': 12,
#  'Песчаная площадь': 12,
#  'Новопесчаная улица': 32,
#  'Анадырский проезд': 36,
#  'улица Малыгина': 36,
#  'Изумрудная улица': 44,
#  'Минусинская улица': 8,
#  'улица Коминтерна': 44,
#  'Радужная улица': 44,
#  'Енисейская улица': 88,
#  'проезд Серебрякова': 44,
#  'улица Амундсена': 8,
#  'Туристская улица': 44,
#  'Походный проезд': 28,
#  'Строительный проезд': 16,
#  'проезд Донелайтиса': 32,
#  'улица Фабрициуса': 40,
#  'Вишнёвая улица': 12,
#  'улица Генерала Белобородова': 60,
#  'площадь Академика Курчатова': 12,
#  'улица Маршала Конева': 8,
#  'улица Алабяна': 36,
#  'улица Черняховского': 4,
#  'улица Маршала Василевского': 24,
#  'Песчаная улица': 16,
#  'проезд Девичьего Поля': 4,
#  'Смоленская площадь': 8,
#  'площадь Новодевичьего Монастыря': 8,
#  'Ельнинская улица': 32,
#  'проезд без названия': 2036,
#  'улица Генерала Глаголева': 24,
#  'Планерная улица': 48,
#  'Снежная улица': 36,
#  'проезд Соломенной Сторожки': 12,
#  'Алёшкинский проезд': 8,
#  'улица Корнейчука': 56,
#  'улица Лескова': 72,
#  'Широкая улица': 92,
#  'улица Бориса Галушкина': 48,
#  'Ростокинский проезд': 24,
#  'Богородское шоссе': 32,
#  'улица Максимова': 12,
#  'улица Рогова': 20,
#  'Талдомская улица': 16,
#  'Керамический проезд': 16,
#  'Весенняя улица': 4,
#  'Лобненская улица': 24,
#  'Карельский бульвар': 28,
#  'Живописная улица': 60,
#  'улица Паршина': 16,
#  'улица Маршала Соколовского': 8,
#  'улица Маршала Новикова': 20,
#  'улица Маршала Вершинина': 4,
#  'улица Твардовского': 44,
#  'Таллинская улица': 48,
#  'Новощукинская улица': 48,
#  'Street': 44,
#  'Дегунинский проезд': 4,
#  'проезд Стратонавтов': 4,
#  'Строгинское шоссе': 24,
#  'Тушинская площадь': 28,
#  'Одинцовская улица': 16,
#  'Туркменский проезд': 4,
#  'Строгинский бульвар': 36,
#  'Ижорский проезд': 12,
#  'Прибрежный проезд': 32,
#  'Неманский проезд': 32,
#  'Гостиничный проезд': 8,
#  'улица Космонавта Волкова': 28,
#  'улица Академика Бочвара': 8,
#  'улица Гамалеи': 24,
#  'улица Софьи Ковалевской': 36,
#  '74-й километр Московской Кольцевой Автодороги': 8,
#  '1-й Силикатный проезд': 28,
#  'Шелепихинское шоссе': 16,
#  '3-я Магистральная улица': 20,
#  '4-я Магистральная улица': 24,
#  'улица Нижние Мнёвники': 52,
#  'улица Сергея Эйзенштейна': 12,
#  'улица Вильгельма Пика': 20,
#  'Берёзовая аллея': 36,
#  'Олонецкая улица': 20,
#  'Отрадная улица': 16,
#  'Отрадный проезд': 12,
#  'Сигнальный проезд': 36,
#  'Продольный проезд': 72,
#  'улица Вилиса Лациса': 40,
#  'Причальный проезд': 8,
#  'Шелепихинская набережная': 16,
#  'Большая Филёвская улица': 64,
#  'Минская улица': 64,
#  'улица Фомичёвой': 16,
#  'Осенний бульвар': 40,
#  'улица Крылатские Холмы': 68,
#  'Рубежный проезд': 8,
#  'Беговая улица': 28,
#  'Магистральный переулок': 8,
#  '2-й Хорошёвский проезд': 20,
#  '5-я Магистральная улица': 4,
#  'улица Заморёнова': 28,
#  '3-я Хорошёвская улица': 40,
#  'Ярославское шоссе': 92,
#  '93-й километр Московской Кольцевой Автодороги': 8,
#  '92-й километр Московской Кольцевой Автодороги': 16,
#  '91-й километр Московской Кольцевой Автодороги': 8,
#  '89-й километр Московской Кольцевой Автодороги': 8,
#  '88-й километр Московской Кольцевой Автодороги': 8,
#  '87-й километр Московской Кольцевой Автодороги': 8,
#  '84-й километр Московской Кольцевой Автодороги': 8,
#  '83-й километр Московской Кольцевой Автодороги': 8,
#  'Лианозовский проезд': 20,
#  'Мелиховская улица': 12,
#  'Белозерская улица': 28,
#  'Мурановская улица': 24,
#  'улица Пришвина': 36,
#  'Бибиревская улица': 44,
#  'Алтуфьевское шоссе': 176,
#  'Костромская улица': 28,
#  'Череповецкая улица': 60,
#  'улица Ивана Сусанина': 28,
#  'Осенняя улица': 32,
#  'Крылатская улица': 80,
#  'Осташковская улица': 36,
#  'Псковская улица': 12,
#  'Зональная улица': 8,
#  'Барвихинская улица': 44,
#  'Запорожская улица': 4,
#  'улица Маршала Неделина': 28,
#  'улица Красных Зорь': 36,
#  'Малая Филёвская улица': 48,
#  'Пинский проезд': 8,
#  'улица Барклая': 64,
#  'улица Толбухина': 16,
#  'Можайское шоссе': 52,
#  'Аминьевское шоссе': 64,
#  'Верейская улица': 40,
#  'Рябиновая улица': 120,
#  '2-й Поперечный проезд': 8,
#  'Абрамцевская улица': 44,
#  'улица Плещеева': 32,
#  'улица Конёнкова': 28,
#  'Илимская улица': 16,
#  'улица Говорова': 24,
#  'Вяземская улица': 12,
#  'Сколковское шоссе': 52,
#  'Беловежская улица': 44,
#  'Ярцевская улица': 32,
#  'улица Артамонова': 20,
#  'улица Кубинка': 12,
#  'улица Боженко': 8,
#  'Варшавское шоссе': 648,
#  'Сумская улица': 20,
#  'Кировоградская улица': 112,
#  'улица Красного Маяка': 76,
#  'Вологодский проезд': 20,
#  'улица Лётчика Бабушкина': 68,
#  'улица Менжинского': 72,
#  'Северодвинская улица': 24,
#  'Шоссейная улица': 164,
#  'Славянский бульвар': 28,
#  'Кременчугская улица': 16,
#  'Гвардейская улица': 8,
#  'Давыдковская улица': 32,
#  'Староможайское шоссе': 12,
#  'Кутузовский проспект': 140,
#  'Большая Дорогомиловская улица': 40,
#  'Бережковская набережная': 36,
#  'Воробьёвское шоссе': 16,
#  'Мосфильмовская улица': 80,
#  'Мичуринский проспект': 168,
#  'улица Косыгина': 56,
#  'Ленинский проспект': 284,
#  'улица Большая Якиманка': 20,
#  'Якиманский проезд': 8,
#  'улица Серафимовича': 12,
#  'Стартовая улица': 48,
#  'проезд Шокальского': 48,
#  'улица Грекова': 28,
#  'Студёный проезд': 32,
#  'проезд Дежнёва': 52,
#  'Тайнинская улица': 24,
#  'Новозаводская улица': 48,
#  'Береговой проезд': 8,
#  'Новофилёвский проезд': 16,
#  'Филёвский бульвар': 36,
#  'Полярная улица': 96,
#  'улица Молодцова': 32,
#  'Ясный проезд': 44,
#  'Северный бульвар': 32,
#  'улица Бестужевых': 28,
#  'Инженерная улица': 24,
#  'Путевой проезд': 32,
#  'улица Декабристов': 60,
#  'улица Хачатуряна': 44,
#  'улица Санникова': 8,
#  'улица Мусоргского': 20,
#  'Челюскинская улица': 24,
#  'Юрловский проезд': 40,
#  'Партизанская улица': 44,
#  'Истринская улица': 12,
#  'Молдавская улица': 16,
#  'Житомирская улица': 4,
#  'Кастанаевская улица': 68,
#  'Молодогвардейская улица': 72,
#  'Заревый проезд': 12,
#  'Сельскохозяйственная улица': 76,
#  'улица Пестеля': 16,
#  'Чертановская улица': 256,
#  'Симферопольский бульвар': 96,
#  'улица 26-ти Бакинских Комиссаров': 36,
#  'Селигерская улица': 4,
#  'Бескудниковский переулок': 4,
#  'улица Академика Янгеля': 24,
#  'Россошанский проезд': 16,
#  '3-й Дорожный проезд': 40,
#  'Дорожная улица': 64,
#  'улица Подольских Курсантов': 68,
#  'Мирской переулок': 20,
#  'Холмогорская улица': 8,
#  'Федоскинская улица': 16,
#  'улица Римского-Корсакова': 36,
#  'улица Яблочкова': 40,
#  'улица Фонвизина': 20,
#  'улица Милашенкова': 40,
#  'Россошанская улица': 16,
#  'Сумской проезд': 20,
#  '1-я Останкинская улица': 48,
#  'Кольская улица': 24,
#  'Чонгарский бульвар': 48,
#  'Днепропетровская улица': 48,
#  'Печорская улица': 20,
#  'улица Гончарова': 16,
#  'улица Руставели': 32,
#  'Огородный проезд': 44,
#  '17-й проезд Марьиной Рощи': 8,
#  'Шереметьевская улица': 52,
#  '5-й проезд Марьиной Рощи': 8,
#  'Полковая улица': 4,
#  'улица Двинцев': 16,
#  'улица Грузинский Вал': 16,
#  'улица Пресненский Вал': 32,
#  'улица Трёхгорный Вал': 4,
#  'Шмитовский проезд': 56,
#  '2-й Красногвардейский проезд': 8,
#  'Новый Берингов проезд': 16,
#  'улица Сергея Макеева': 8,
#  'Стрелецкая улица': 4,
#  '3-й проезд Марьиной Рощи': 8,
#  'Востряковский проезд': 52,
#  'Булатниковская улица': 36,
#  'Медынская улица': 44,
#  'Харьковская улица': 16,
#  'Булатниковский проезд': 48,
#  'Болотниковская улица': 84,
#  'Большая Тульская улица': 28,
#  'Подольское шоссе': 8,
#  'Павловская улица': 4,
#  'Большая Серпуховская улица': 36,
#  'Серпуховская площадь': 8,
#  'улица Большая Полянка': 32,
#  'Люсиновская улица': 32,
#  'улица Добролюбова': 20,
#  'улица Советской Армии': 24,
#  'Трифоновская улица': 48,
#  'Олимпийский проспект': 32,
#  'улица Дурова': 20,
#  'Самотёчная улица': 8,
#  'Малая Ботаническая улица': 8,
#  'Мясницкая улица': 16,
#  'Ростокинская улица': 20,
#  'Малахитовая улица': 32,
#  'улица Докукина': 28,
#  '1-я улица Леонова': 16,
#  '1-й Ботанический проезд': 4,
#  'Лазоревый проезд': 8,
#  '2-й Ботанический проезд': 8,
#  'улица Седова': 8,
#  'проезд Русанова': 28,
#  'Краснопролетарская улица': 24,
#  'Останкинский проезд': 8,
#  'Селезнёвская улица': 12,
#  'Нахимовский проспект': 128,
#  'Коломенская улица': 40,
#  'улица Новинки': 20,
#  'проспект Андропова': 108,
#  'Нагатинская набережная': 68,
#  'Судостроительная улица': 116,
#  '1-й Нагатинский проезд': 8,
#  'Нагатинская улица': 60,
#  'Ереванская улица': 32,
#  'Кавказский бульвар': 56,
#  'Пролетарский проспект': 92,
#  'Каширское шоссе': 232,
#  'улица Каховка': 84,
#  'улица Намёткина': 12,
#  'Профсоюзная улица': 224,
#  'Страстной бульвар': 12,
#  'Долгоруковская улица': 24,
#  'Большая Переяславская улица': 16,
#  'Каланчёвская улица': 36,
#  'Русаковская улица': 44,
#  'улица Стромынка': 60,
#  'Электрозаводская улица': 48,
#  'Ферганский проезд': 28,
#  'Самаркандский бульвар': 52,
#  'улица Хлобыстова': 44,
#  'Ташкентская улица': 52,
#  'улица Образцова': 16,
#  'Перуновский переулок': 4,
#  'улица Новая Башиловка': 16,
#  'Балаклавский проспект': 80,
#  'улица Обручева': 76,
#  'Ферганская улица': 28,
#  '2-й Грайвороновский проезд': 32,
#  'Грайвороновская улица': 28,
#  'Люблинская улица': 172,
#  'Черноморский бульвар': 36,
#  'Ялтинская улица': 8,
#  'Стрельбищенский переулок': 24,
#  'Артековская улица': 8,
#  'Оружейный переулок': 8,
#  'Садовая-Триумфальная улица': 8,
#  'улица Павла Корчагина': 32,
#  'Новоалексеевская улица': 16,
#  '3-я Мытищинская улица': 8,
#  'площадь Академика Люльки': 4,
#  'улица Сокольнический Вал': 44,
#  'Поперечный просек': 60,
#  'Краснобогатырская улица': 88,
#  'улица Измайловский Вал': 24,
#  'Семёновская площадь': 12,
#  'Щербаковская улица': 32,
#  'Измайловский проспект': 36,
#  'Первомайская улица': 168,
#  'улица Преображенский Вал': 20,
#  'улица Олений Вал': 16,
#  'Большая Ширяевская улица': 16,
#  'Миллионная улица': 16,
#  'Новорязанская улица': 24,
#  'Бакунинская улица': 44,
#  'Электрозаводский мост': 16,
#  'Вельяминовская улица': 16,
#  'Ткацкая улица': 32,
#  'Большая Оленья улица': 20,
#  'Преображенская улица': 16,
#  'Халтуринская улица': 16,
#  'Большая Семёновская улица': 28,
#  'Спартаковская улица': 8,
#  'Ивантеевская улица': 64,
#  '4-й проезд Подбельского': 8,
#  '1-я Прогонная улица': 4,
#  'Малая Черкизовская улица': 12,
#  'Большая Черкизовская улица': 80,
#  'Просторная улица': 16,
#  'Алымов переулок': 4,
#  '3-я Гражданская улица': 8,
#  'Игральная улица': 12,
#  'улица Сайкина': 8,
#  'Велозаводская улица': 12,
#  'улица Ленинская Слобода': 16,
#  'улица Мастеркова': 12,
#  'Автозаводская улица': 76,
#  'Битцевский проезд': 24,
#  'Коломенская набережная': 44,
#  'улица Симоновский Вал': 40,
#  'улица Большие Каменщики': 24,
#  'Затонная улица': 20,
#  'Якорная улица': 16,
#  'улица Трофимова': 60,
#  'улица Газопровод': 24,
#  'Бойцовая улица': 32,
#  '4-я Гражданская улица': 8,
#  'улица Богородский Вал': 8,
#  'Потешная улица': 16,
#  'Русаковская набережная': 4,
#  '1-я Рыбинская улица': 4,
#  'Водопроводный переулок': 4,
#  'проспект Будённого': 136,
#  'улица Бориса Жигулёнкова': 16,
#  '8-я улица Соколиной Горы': 8,
#  'Сиреневый бульвар': 76,
#  'Щёлковский проезд': 4,
#  'Щёлковское шоссе': 156,
#  'Преображенская площадь': 8,
#  'Вербная улица': 8,
#  'шоссе Энтузиастов': 336,
#  '2-й Полевой переулок': 12,
#  'Котляковская улица': 20,
#  '2-й Котляковский переулок': 12,
#  '1-й Варшавский проезд': 8,
#  'Каширский проезд': 4,
#  'Хабаровская улица': 64,
#  'улица Гастелло': 32,
#  '15-я Парковая улица': 48,
#  'улица Шумкина': 16,
#  'Старая Басманная улица': 28,
#  'улица Земляной Вал': 60,
#  'Костомаровский переулок': 24,
#  'улица Сергия Радонежского': 20,
#  'Новорогожская улица': 16,
#  'Севастопольский проспект': 180,
#  'Азовская улица': 32,
#  'Коломенское шоссе': 8,
#  'улица Садовники': 8,
#  'Коломенский проезд': 36,
#  'улица Академика Миллионщикова': 44,
#  'Донская улица': 4,
#  'Зелёный проспект': 168,
#  '3-я Владимирская улица': 32,
#  '3-я Рыбинская улица': 8,
#  'Рабочая улица': 28,
#  'улица Лобачика': 8,
#  'Камчатская улица': 20,
#  'Сахалинская улица': 4,
#  'Уральская улица': 44,
#  '9-я Парковая улица': 52,
#  'Курганская улица': 12,
#  'Уссурийская улица': 24,
#  'Измайловский бульвар': 60,
#  '3-я Парковая улица': 48,
#  'улица Радио': 40,
#  'Бауманская улица': 68,
#  'Протопоповский переулок': 36,
#  'Делегатская улица': 4,
#  '3-й Самотёчный переулок': 20,
#  'улица Достоевского': 12,
#  'Ольховская улица': 8,
#  'Красноказарменная улица': 76,
#  'Байкальская улица': 60,
#  'Чусовская улица': 16,
#  'Иркутская улица': 12,
#  '2-й Иртышский проезд': 20,
#  'улица Бирюсинка': 28,
#  'Амурская улица': 24,
#  'Одесская улица': 16,
#  'улица Дмитрия Ульянова': 64,
#  'Нагорная улица': 56,
#  'Красноярская улица': 24,
#  'Алтайская улица': 52,
#  'Спартаковская площадь': 4,
#  'улица Молостовых': 44,
#  'Свободный проспект': 92,
#  'Вешняковская улица': 84,
#  'улица Красный Казанец': 60,
#  'Саянская улица': 36,
#  'улица Сталеваров': 60,
#  'улица Старый Гай': 16,
#  'Кетчерская улица': 36,
#  'Напольный проезд': 16,
#  'Снайперская улица': 12,
#  'улица Молдагуловой': 48,
#  'Фрязевская улица': 20,
#  'Мартеновская улица': 24,
#  'Новогиреевская улица': 52,
#  'Перовская улица': 84,
#  'Кусковская улица': 36,
#  'улица Плющева': 24,
#  'Электродная улица': 20,
#  'улица Уткина': 12,
#  'Окружной проезд': 56,
#  'Вольная улица': 24,
#  'Федеративный проспект': 52,
#  'улица Металлургов': 20,
#  '2-я Владимирская улица': 44,
#  'улица Плеханова': 56,
#  'улица Аносова': 4,
#  'Кусковский тупик': 4,
#  'улица Лазо': 20,
#  'Московский проспект': 44,
#  'Ломоносовский проспект': 152,
#  '1-я Владимирская улица': 40,
#  'Челябинская улица': 28,
#  'Большой Купавенский проезд': 28,
#  'Малый Купавенский проезд': 8,
#  '16-я Парковая улица': 24,
#  '106-й километр Московской Кольцевой Автодороги': 8,
#  '108-й километр Московской Кольцевой Автодороги': 8,
#  'улица Юности': 72,
#  'улица Паперника': 12,
#  'Рязанский проспект': 160,
#  'Монтажная улица': 32,
#  'Открытое шоссе': 100,
#  'Измайловское шоссе': 24,
#  'улица Чечулина': 28,
#  'Реутовская улица': 40,
#  'аллея Жемчуговой': 24,
#  'улица Академика Скрябина': 48,
#  'Электролитный проезд': 28,
#  'улица Ремизова': 20,
#  'проезд Карамзина': 48,
#  'Голубинская улица': 80,
#  'Ясногорская улица': 16,
#  'улица Айвазовского': 16,
#  'улица Островитянова': 96,
#  'Тарусская улица': 24,
#  '5-я улица Соколиной Горы': 8,
#  'Яснополянская улица': 8,
#  'улица Михайлова': 44,
#  'улица Коновалова': 16,
#  'Кузьминская улица': 16,
#  'улица Миклухо-Маклая': 84,
#  'улица Введенского': 52,
#  'Нижегородская улица': 68,
#  'Таганская улица': 24,
#  'Оршанская улица': 8,
#  'улица Маршала Тимошенко': 24,
#  '2-й Южнопортовый проезд': 4,
#  'Кунцевская улица': 8,
#  'Полоцкая улица': 12,
#  'улица Ивана Франко': 36,
#  'улица Василия Ботылёва': 16,
#  'Обводное шоссе': 12,
#  'улица Академика Павлова': 32,
#  'Новоясеневский проспект': 128,
#  'Литовский бульвар': 56,
#  '2-я Мякининская улица': 4,
#  'Бобруйская улица': 20,
#  'улица Екатерины Будановой': 8,
#  'улица Коцюбинского': 8,
#  'Никитский бульвар': 8,
#  '1-й Поперечный проезд': 8,
#  'Раушская набережная': 4,
#  'Космодамианская набережная': 12,
#  'улица Зацепский Вал': 16,
#  'Садовническая улица': 20,
#  'Болотная улица': 4,
#  'улица Новый Арбат': 16,
#  'Волгоградский проспект': 200,
#  '2-я улица Машиностроения': 44,
#  '1-я улица Машиностроения': 24,
#  'улица Вострухина': 20,
#  'улица Чугунные Ворота': 16,
#  'Сормовская улица': 16,
#  'улица Нижняя Хохловка': 4,
#  '7-я Парковая улица': 20,
#  '5-я Парковая улица': 28,
#  'Зубовская улица': 8,
#  'улица Пречистенка': 32,
#  'Гоголевский бульвар': 24,
#  'улица Юных Ленинцев': 88,
#  'Таганская площадь': 12,
#  'Верхняя Радищевская улица': 12,
#  'Яузская улица': 16,
#  'Москворецкая набережная': 24,
#  'Кремлёвская набережная': 4,
#  'Пречистенская набережная': 12,
#  'Подгорская набережная': 4,
#  'Нижняя Радищевская улица': 8,
#  'улица Александра Солженицына': 12,
#  'Николоямская улица': 40,
#  'Андроньевский проезд': 8,
#  'Волочаевская улица': 52,
#  'Душинская улица': 8,
#  'Главная улица': 4,
#  'Воронцовская улица': 24,
#  '1-я Дубровская улица': 32,
#  'Шарикоподшипниковская улица': 48,
#  '1-й Сетуньский проезд': 8,
#  '4-й Сетуньский проезд': 4,
#  '2-й Сетуньский проезд': 8,
#  'площадь Киевского Вокзала': 40,
#  'улица Покровка': 32,
#  'улица Маросейка': 8,
#  'Авиамоторная улица': 84,
#  '2-я Кабельная улица': 4,
#  '2-й Кабельный проезд': 4,
#  'Славянская площадь': 20,
#  'Новочерёмушкинская улица': 64,
#  'проезд Стройкомбината': 16,
#  'Очаковское шоссе': 24,
#  'Матвеевская улица': 32,
#  'Веерная улица': 40,
#  'Нежинская улица': 36,
#  'Староволынская улица': 24,
#  'проспект Вернадского': 252,
#  'Красноармейская улица': 28,
#  'Тверской бульвар': 24,
#  'улица Гарибальди': 36,
#  'улица Архитектора Власова': 36,
#  'Комсомольский проспект': 84,
#  'улица Остоженка': 24,
#  'Подольская улица': 24,
#  'улица Перерва': 108,
#  'улица Нижние Поля': 32,
#  'Волжский бульвар': 84,
#  'Саратовская улица': 24,
#  'улица Лобачевского': 92,
#  'Керченская улица': 16,
#  'Окская улица': 32,
#  'улица Фёдора Полетаева': 32,
#  'Жигулёвская улица': 12,
#  'улица Шкулёва': 16,
#  'Университетский проспект': 52,
#  'Семёновский проезд': 24,
#  'улица Семёновский Вал': 8,
#  'Доброслободская улица': 24,
#  'Новая Басманная улица': 28,
#  'Красноворотский проезд': 4,
#  'Белореченская улица': 52,
#  'Краснодарская улица': 84,
#  'улица Полбина': 60,
#  'улица Гурьянова': 64,
#  'Перовское шоссе': 40,
#  'шоссе Фрезер': 28,
#  '1-я Фрезерная улица': 12,
#  '5-я Кабельная улица': 24,
#  'Новочеркасский бульвар': 56,
#  'Донецкая улица': 28,
#  'улица Олеко Дундича': 8,
#  'улица Маршала Голованова': 32,
#  'улица Горбунова': 28,
#  'улица Судакова': 20,
#  'Краснодонская улица': 80,
#  'Южнопортовая улица': 76,
#  'улица Коштоянца': 36,
#  'улица Удальцова': 76,
#  'Багратионовский проезд': 16,
#  'улица Полосухина': 4,
#  'Батайский проезд': 52,
#  'Ставропольская улица': 68,
#  '13-я Парковая улица': 12,
#  'Измайловская площадь': 8,
#  'Измайловский проезд': 8,
#  'Никитинская улица': 24,
#  '3-я Прядильная улица': 4,
#  '1-я Парковая улица': 8,
#  'Тихорецкий бульвар': 20,
#  'улица Рогожский Вал': 20,
#  'Абельмановская улица': 12,
#  '3-й Крутицкий переулок': 24,
#  'Солдатская улица': 8,
#  'Угрешская улица': 44,
#  'Большая Андроньевская улица': 16,
#  'Зеленодольский проезд': 8,
#  'улица Академика Волгина': 36,
#  'проспект 60-летия Октября': 40,
#  'Безымянный проезд': 4,
#  'Садовая-Черногрязская улица': 12,
#  'Лермонтовская площадь': 8,
#  'Садовая-Спасская улица': 16,
#  'Малая Сухаревская площадь': 12,
#  'Самотёчная площадь': 8,
#  'Садовая-Самотёчная улица': 16,
#  'Большая Садовая улица': 8,
#  'Садовая-Кудринская улица': 24,
#  'Зубовский бульвар': 16,
#  'улица Крымский Вал': 12,
#  'Валовая улица': 12,
#  'Большой Краснохолмский мост': 8,
#  'улица Пржевальского': 16,
#  'Большая Очаковская улица': 52,
#  'Никулинская улица': 20,
#  'Петровский бульвар': 12,
#  'Банный переулок': 8,
#  'Новосущёвский переулок': 16,
#  'Минаевский переулок': 8,
#  'улица Николая Химушина': 16,
#  'улица Академика Челомея': 12,
#  'улица Новаторов': 36,
#  'улица Воронцовские Пруды': 4,
#  'Вильнюсская улица': 16,
#  'Озёрная улица': 44,
#  'проектируемый проезд № 1980': 20,
#  'улица Бутлерова': 28,
#  'Мытная улица': 40,
#  'улица Шухова': 4,
#  'улица Академика Пилюгина': 44,
#  'улица Кравченко': 24,
#  'Лубянская площадь': 16,
#  'Устьинская набережная': 4,
#  'улица Марии Ульяновой': 20,
#  'улица Академика Хохлова': 16,
#  'улица Лебедева': 20,
#  'улица Паустовского': 16,
#  'Борисовский проезд': 48,
#  'Смоленская улица': 8,
#  'проезд Нансена': 8,
#  'Грузинский переулок': 4,
#  'Ясеневая улица': 72,
#  'Фрунзенская набережная': 56,
#  'Сущёвская улица': 20,
#  'Нововоротниковский переулок': 4,
#  'Большая Грузинская улица': 32,
#  'Малая Грузинская улица': 24,
#  'Конюшковская улица': 16,
#  'улица Барышиха': 80,
#  'улица Борисовские Пруды': 104,
#  'Малая Андроньевская улица': 8,
#  'Братеевская улица': 44,
#  'Хордовый проезд': 20,
#  'Паромная улица': 20,
#  'Дубининская улица': 56,
#  'Холодильный переулок': 16,
#  'улица Даниловский Вал': 16,
#  'Елецкая улица': 20,
#  'площадь Крестьянская Застава': 4,
#  'Воронежская улица': 52,
#  'Сокольническая площадь': 8,
#  'Остаповский проезд': 8,
#  'Иловайская улица': 24,
#  'Софийская набережная': 4,
#  'Верхняя Красносельская улица': 32,
#  'Липецкая улица': 96,
#  'Бакинская улица': 40,
#  'улица Москворечье': 40,
#  'Промышленная улица': 32,
#  'Деловая улица': 8,
#  'улица Кошкина': 12,
#  'Кантемировская улица': 52,
#  'улица Бехтерева': 40,
#  'Севанская улица': 32,
#  'Ряжская улица': 16,
#  'Бирюлёвская улица': 48,
#  'Касимовская улица': 20,
#  'Лебедянская улица': 56,
#  'Загорьевская улица': 20,
#  'Михневская улица': 28,
#  'улица Серпуховский Вал': 40,
#  'Загорьевский проезд': 32,
#  'Каспийская улица': 76,
#  'улица Медиков': 24,
#  'Шипиловская улица': 64,
#  'Шипиловский проезд': 84,
#  'Домодедовская улица': 52,
#  'Ореховый бульвар': 100,
#  'улица Маршала Захарова': 32,
#  'Элеваторная улица': 4,
#  'Товарищеская улица': 4,
#  'Новоспасский проезд': 16,
#  'Новохохловская улица': 28,
#  'Луганская улица': 16,
#  'Новоостаповская улица': 32,
#  'Полимерная улица': 8,
#  '3-й Павелецкий проезд': 24,
#  'Павелецкая набережная': 12,
#  'Дербеневская набережная': 24,
#  'Кожевническая улица': 24,
#  'Носовихинское шоссе': 24,
#  'Городецкая улица': 32,
#  'Новокосинская улица': 56,
#  'Салтыковская улица': 96,
#  'улица Улофа Пальме': 4,
#  'улица Довженко': 24,
#  'улица Винокурова': 28,
#  'улица Шверника': 16,
#  'улица Гримау': 16,
#  'Менделеевская улица': 12,
#  'улица Богатырский Мост': 12,
#  'Елоховская площадь': 4,
#  '1-й Дербеневский переулок': 8,
#  'улица Маршала Чуйкова': 24,
#  'Михневский проезд': 16,
#  'Никольско-Архангельский проезд': 12,
#  '2-й километр Московской Кольцевой Автодороги': 8,
#  '3-й километр Московской Кольцевой Автодороги': 8,
#  'Задонский проезд': 52,
#  'улица Мусы Джалиля': 60,
#  'Ореховый проезд': 20,
#  'улица Генерала Белова': 56,
#  'Кустанайская улица': 20,
#  'Гурьевский проезд': 32,
#  'Тамбовская улица': 8,
#  'Зеленодольская улица': 16,
#  'улица Маршала Шестопалова': 36,
#  'улица Павла Андреева': 4,
#  'Ключевая улица': 44,
#  'Нижняя Краснохолмская улица': 4,
#  'Даниловская набережная': 16,
#  'Алма-Атинская улица': 8,
#  'Суздальская улица': 68,
#  'улица Строителей': 20,
#  'Юрьевский переулок': 16,
#  'Ухтомская улица': 20,
#  'Нагорный проезд': 24,
#  'улица Шаболовка': 32,
#  'улица Кржижановского': 60,
#  'Большая Черёмушкинская улица': 76,
#  'Загородное шоссе': 48,
#  'улица Вавилова': 92,
#  'улица Орджоникидзе': 16,
#  'Новокузнецкая улица': 24,
#  'Садовнический проезд': 16,
#  'Устьинский проезд': 16,
#  'Яузский бульвар': 4,
#  'Хохловская площадь': 4,
#  'Чистопрудный бульвар': 16,
#  'Покровский бульвар': 12,
#  'Лосиноостровская улица': 64,
#  'Пермская улица': 24,
#  '6-й Лучевой просек': 12,
#  'Белокаменное шоссе': 8,
#  'Яузская аллея': 8,
#  '6-я Радиальная улица': 28,
#  'Пятницкая улица': 20,
#  'улица Большая Ордынка': 24,
#  'Большой Москворецкий мост': 12,
#  '2-й Боткинский проезд': 28,
#  '1-й Боткинский проезд': 8,
#  'улица Матросская Тишина': 36,
#  'Большая Почтовая улица': 32,
#  'Малая Почтовая улица': 12,
#  '1-й Капотнинский проезд': 44,
#  'улица Верхние Поля': 112,
#  'Чагинская улица': 24,
#  'улица Капотня': 32,
#  '14-й километр Московской Кольцевой Автодороги': 8,
#  '11-й километр Московской Кольцевой Автодороги': 8,
#  'улица Цюрупы': 32,
#  'улица Крупской': 16,
#  '4-й Загородный проезд': 20,
#  'Кубанская улица': 4,
#  'Курская улица': 4,
#  '7-я улица Текстильщиков': 4,
#  'Новоцарицынское шоссе': 28,
#  '1-я Радиальная улица': 4,
#  '3-я Радиальная улица': 16,
#  '40-й километр Московской Кольцевой Автодороги': 8,
#  '38-й километр Московской Кольцевой Автодороги': 8,
#  '37-й километр Московской Кольцевой Автодороги': 8,
#  '35-й километр Московской Кольцевой Автодороги': 8,
#  '34-й километр Московской Кольцевой Автодороги': 16,
#  '33-й километр Московской Кольцевой Автодороги': 8,
#  '32-й километр Московской Кольцевой Автодороги': 16,
#  '31-й километр Московской Кольцевой Автодороги': 8,
#  '29-й километр Московской Кольцевой Автодороги': 8,
#  '27-й километр Московской Кольцевой Автодороги': 8,
#  '25-й километр Московской Кольцевой Автодороги': 4,
#  'Шелепихинский мост': 4,
#  '2-я Брестская улица': 8,
#  'улица Тёплый Стан': 56,
#  'проезд Одоевского': 16,
#  'Малая Тульская улица': 20,
#  'улица Раменки': 16,
#  'улица Кедрова': 16,
#  'улица Инессы Арманд': 20,
#  'Тропарёвская улица': 28,
#  '7-я Кожуховская улица': 16,
#  'улица Петра Романова': 4,
#  '6-я Кожуховская улица': 8,
#  'Новомарьинская улица': 48,
#  'улица Ивана Бабушкина': 8,
#  'Соймоновский проезд': 4,
#  'улица Академика Варги': 44,
#  'Рочдельская улица': 16,
#  'улица Генерала Тюленева': 32,
#  '3-я Никопольская улица': 4,
#  'Мелитопольская улица': 4,
#  'проезд Олимпийской Деревни': 12,
#  'улица Рокотова': 12,
#  'Соловьиный проезд': 24,
#  'Боровское шоссе': 296,
#  'Солнцевский проспект': 32,
#  'улица Богданова': 32,
#  '48-й километр Московской Кольцевой Автодороги': 12,
#  'улица Академика Анохина': 60,
#  'улица Академика Бакулева': 24,
#  'Санаторная аллея': 8,
#  'Теплостанский проезд': 4,
#  'Троекуровский проезд': 12,
#  'улица Тюрина': 4,
#  'Попутная улица': 24,
#  'улица 50 лет Октября': 32,
#  'Донбасская улица': 4,
#  'Верхняя Сыромятническая улица': 8,
#  'Гаврикова улица': 8,
#  'Марксистская улица': 40,
#  'бульвар Энтузиастов': 12,
#  'Инициативная улица': 16,
#  'Елизаветинский переулок': 16,
#  ...}

# %%
sorted(streets.items(), key=lambda item: item[1], reverse=True)
# Out:
# [('проезд без названия', 2036),
#  ('Варшавское шоссе', 648),
#  ('Калужское шоссе', 564),
#  ('шоссе Энтузиастов', 336),
#  ('проспект Мира', 296),
#  ('Боровское шоссе', 296),
#  ('Дмитровское шоссе', 284),
#  ('Ленинский проспект', 284),
#  ('Чертановская улица', 256),
#  ('проспект Вернадского', 252),
#  ('Каширское шоссе', 232),
#  ('Ленинградское шоссе', 224),
#  ('Профсоюзная улица', 224),
#  ('Волгоградский проспект', 200),
#  ('Центральная улица', 192),
#  ('Волоколамское шоссе', 184),
#  ('Севастопольский проспект', 180),
#  ('Алтуфьевское шоссе', 176),
#  ('Люблинская улица', 172),
#  ('Мичуринский проспект', 168),
#  ('Первомайская улица', 168),
#  ('Зелёный проспект', 168),
#  ('Рублёвское шоссе', 164),
#  ('Шоссейная улица', 164),
#  ('Рязанский проспект', 160),
#  ('Щёлковское шоссе', 156),
#  ('Ломоносовский проспект', 152),
#  ('Ленинградский проспект', 148),
#  ('улица Героев Панфиловцев', 144),
#  ('улица Свободы', 140),
#  ('Кутузовский проспект', 140),
#  ('проспект Будённого', 136),
#  ('Киевское шоссе', 132),
#  ('улица Александры Монаховой', 132),
#  ('Нахимовский проспект', 128),
#  ('Новоясеневский проспект', 128),
#  ('Рябиновая улица', 120),
#  ('Привольная улица', 120),
#  ('Судостроительная улица', 116),
#  ('Дубнинская улица', 112),
#  ('Кировоградская улица', 112),
#  ('улица Верхние Поля', 112),
#  ('проспект Андропова', 108),
#  ('улица Перерва', 108),
#  ('улица Борисовские Пруды', 104),
#  ('Фестивальная улица', 100),
#  ('Хорошёвское шоссе', 100),
#  ('улица Народного Ополчения', 100),
#  ('Открытое шоссе', 100),
#  ('Ореховый бульвар', 100),
#  ('Большая Академическая улица', 96),
#  ('Полярная улица', 96),
#  ('Симферопольский бульвар', 96),
#  ('улица Островитянова', 96),
#  ('Липецкая улица', 96),
#  ('Салтыковская улица', 96),
#  ('Коровинское шоссе', 92),
#  ('Широкая улица', 92),
#  ('Ярославское шоссе', 92),
#  ('Пролетарский проспект', 92),
#  ('Свободный проспект', 92),
#  ('улица Лобачевского', 92),
#  ('улица Вавилова', 92),
#  ('Бескудниковский бульвар', 88),
#  ('Енисейская улица', 88),
#  ('Краснобогатырская улица', 88),
#  ('улица Юных Ленинцев', 88),
#  ('улица Сущёвский Вал', 84),
#  ('Тимирязевская улица', 84),
#  ('проспект Маршала Жукова', 84),
#  ('Болотниковская улица', 84),
#  ('улица Каховка', 84),
#  ('Вешняковская улица', 84),
#  ('Перовская улица', 84),
#  ('улица Миклухо-Маклая', 84),
#  ('Авиамоторная улица', 84),
#  ('Комсомольский проспект', 84),
#  ('Волжский бульвар', 84),
#  ('Краснодарская улица', 84),
#  ('Шипиловский проезд', 84),
#  ('улица Александра Печерского', 84),
#  ('Кронштадтский бульвар', 80),
#  ('Крылатская улица', 80),
#  ('Мосфильмовская улица', 80),
#  ('Балаклавский проспект', 80),
#  ('Большая Черкизовская улица', 80),
#  ('Голубинская улица', 80),
#  ('Краснодонская улица', 80),
#  ('улица Барышиха', 80),
#  ('Панфиловский проспект', 80),
#  ('улица Красного Маяка', 76),
#  ('Сельскохозяйственная улица', 76),
#  ('улица Обручева', 76),
#  ('Автозаводская улица', 76),
#  ('Сиреневый бульвар', 76),
#  ('Красноказарменная улица', 76),
#  ('Южнопортовая улица', 76),
#  ('улица Удальцова', 76),
#  ('Каспийская улица', 76),
#  ('Большая Черёмушкинская улица', 76),
#  ('Пятницкое шоссе', 76),
#  ('улица Лескова', 72),
#  ('Продольный проезд', 72),
#  ('улица Менжинского', 72),
#  ('Молодогвардейская улица', 72),
#  ('улица Юности', 72),
#  ('Ясеневая улица', 72),
#  ('Южнобутовская улица', 72),
#  ('Смольная улица', 68),
#  ('улица Академика Королёва', 68),
#  ('улица Кулакова', 68),
#  ('бульвар Яна Райниса', 68),
#  ('улица Крылатские Холмы', 68),
#  ('улица Лётчика Бабушкина', 68),
#  ('Кастанаевская улица', 68),
#  ('улица Подольских Курсантов', 68),
#  ('Нагатинская набережная', 68),
#  ('Бауманская улица', 68),
#  ('Нижегородская улица', 68),
#  ('Ставропольская улица', 68),
#  ('Суздальская улица', 68),
#  ('Ангарская улица', 64),
#  ('улица Маршала Бирюзова', 64),
#  ('улица Маршала Катукова', 64),
#  ('Большая Филёвская улица', 64),
#  ('Минская улица', 64),
#  ('улица Барклая', 64),
#  ('Аминьевское шоссе', 64),
#  ('Дорожная улица', 64),
#  ('Ивантеевская улица', 64),
#  ('Хабаровская улица', 64),
#  ('улица Дмитрия Ульянова', 64),
#  ('Новочерёмушкинская улица', 64),
#  ('улица Гурьянова', 64),
#  ('Шипиловская улица', 64),
#  ('Лосиноостровская улица', 64),
#  ('улица Авиаторов', 64),
#  ('Чечёрский проезд', 64),
#  ('Большой бульвар', 64),
#  ('улица Генерала Белобородова', 60),
#  ('Живописная улица', 60),
#  ('Череповецкая улица', 60),
#  ('улица Декабристов', 60),
#  ('Нагатинская улица', 60),
#  ('улица Стромынка', 60),
#  ('Поперечный просек', 60),
#  ('улица Трофимова', 60),
#  ('улица Земляной Вал', 60),
#  ('Измайловский бульвар', 60),
#  ('Байкальская улица', 60),
#  ('улица Красный Казанец', 60),
#  ('улица Сталеваров', 60),
#  ('улица Полбина', 60),
#  ('улица Мусы Джалиля', 60),
#  ('улица Кржижановского', 60),
#  ('улица Академика Анохина', 60),
#  ('Новокуркинское шоссе', 60),
#  ('улица Зои и Александра Космодемьянских', 56),
#  ('Михалковская улица', 56),
#  ('Митинская улица', 56),
#  ('Бутырская улица', 56),
#  ('Ботаническая улица', 56),
#  ('улица Корнейчука', 56),
#  ('улица Косыгина', 56),
#  ('Шмитовский проезд', 56),
#  ('Кавказский бульвар', 56),
#  ('Нагорная улица', 56),
#  ('Окружной проезд', 56),
#  ('улица Плеханова', 56),
#  ('Литовский бульвар', 56),
#  ('Новочеркасский бульвар', 56),
#  ('Фрунзенская набережная', 56),
#  ('Дубининская улица', 56),
#  ('Лебедянская улица', 56),
#  ('Новокосинская улица', 56),
#  ('улица Генерала Белова', 56),
#  ('улица Тёплый Стан', 56),
#  ('Поречная улица', 56),
#  ('улица Адмирала Лазарева', 56),
#  ('проспект Генерала Алексеева', 56),
#  ('улица 800-летия Москвы', 52),
#  ('Флотская улица', 52),
#  ('улица Исаковского', 52),
#  ('Таманская улица', 52),
#  ('улица Нижние Мнёвники', 52),
#  ('Можайское шоссе', 52),
#  ('Сколковское шоссе', 52),
#  ('проезд Дежнёва', 52),
#  ('Шереметьевская улица', 52),
#  ('Востряковский проезд', 52),
#  ('Самаркандский бульвар', 52),
#  ('Ташкентская улица', 52),
#  ('9-я Парковая улица', 52),
#  ('Алтайская улица', 52),
#  ('Новогиреевская улица', 52),
#  ('Федеративный проспект', 52),
#  ('улица Введенского', 52),
#  ('Волочаевская улица', 52),
#  ('Университетский проспект', 52),
#  ('Белореченская улица', 52),
#  ('Батайский проезд', 52),
#  ('Большая Очаковская улица', 52),
#  ('Воронежская улица', 52),
#  ('Кантемировская улица', 52),
#  ('Домодедовская улица', 52),
#  ('Задонский проезд', 52),
#  ('бульвар Дмитрия Донского', 52),
#  ('Большая Косинская улица', 52),
#  ('улица Марьинский Парк', 52),
#  ('Клязьминская улица', 48),
#  ('Зеленоградская улица', 48),
#  ('Авиационная улица', 48),
#  ('Большая Пироговская улица', 48),
#  ('Планерная улица', 48),
#  ('улица Бориса Галушкина', 48),
#  ('Таллинская улица', 48),
#  ('Новощукинская улица', 48),
#  ('Малая Филёвская улица', 48),
#  ('Стартовая улица', 48),
#  ('проезд Шокальского', 48),
#  ('Новозаводская улица', 48),
#  ('1-я Останкинская улица', 48),
#  ('Чонгарский бульвар', 48),
#  ('Днепропетровская улица', 48),
#  ('Булатниковский проезд', 48),
#  ('Трифоновская улица', 48),
#  ('Электрозаводская улица', 48),
#  ('15-я Парковая улица', 48),
#  ('3-я Парковая улица', 48),
#  ('улица Молдагуловой', 48),
#  ('улица Академика Скрябина', 48),
#  ('проезд Карамзина', 48),
#  ('Шарикоподшипниковская улица', 48),
#  ('Борисовский проезд', 48),
#  ('Бирюлёвская улица', 48),
#  ('Загородное шоссе', 48),
#  ('Новомарьинская улица', 48),
#  ('Родниковая улица', 48),
#  ('2-я Вольская улица', 48),
#  ('Лухмановская улица', 48),
#  ('Железнодорожная улица', 48),
#  ('улица Корнея Чуковского', 48),
#  ('Онежская улица', 44),
#  ('Сходненская улица', 44),
#  ('Лодочная улица', 44),
#  ('улица Берзарина', 44),
#  ('улица Василия Петушкова', 44),
#  ('улица Куусинена', 44),
#  ('Изумрудная улица', 44),
#  ('улица Коминтерна', 44),
#  ('Радужная улица', 44),
#  ('проезд Серебрякова', 44),
#  ('Туристская улица', 44),
#  ('улица Твардовского', 44),
#  ('Street', 44),
#  ('Бибиревская улица', 44),
#  ('Барвихинская улица', 44),
#  ('Абрамцевская улица', 44),
#  ('Беловежская улица', 44),
#  ('Ясный проезд', 44),
#  ('улица Хачатуряна', 44),
#  ('Партизанская улица', 44),
#  ('Огородный проезд', 44),
#  ('Медынская улица', 44),
#  ('Русаковская улица', 44),
#  ('улица Хлобыстова', 44),
#  ('улица Сокольнический Вал', 44),
#  ('Бакунинская улица', 44),
#  ('Коломенская набережная', 44),
#  ('улица Академика Миллионщикова', 44),
#  ('Уральская улица', 44),
#  ('улица Молостовых', 44),
#  ('2-я Владимирская улица', 44),
#  ('Московский проспект', 44),
#  ('улица Михайлова', 44),
#  ('2-я улица Машиностроения', 44),
#  ('Угрешская улица', 44),
#  ('Озёрная улица', 44),
#  ('улица Академика Пилюгина', 44),
#  ('Братеевская улица', 44),
#  ('Ключевая улица', 44),
#  ('1-й Капотнинский проезд', 44),
#  ('улица Академика Варги', 44),
#  ('улица Генерала Дорохова', 44),
#  ('Дубравная улица', 44),
#  ('улица Поляны', 44),
#  ('улица Адмирала Корнилова', 44),
#  ('Венёвская улица', 44),
#  ('Бартеневская улица', 44),
#  ('улица Каменка', 44),
#  ('Центральный проспект', 44),
#  ('улица Ленина', 44),
#  ('Сосновая аллея', 44),
#  ('Октябрьский проспект', 44),
#  ('Старопетровский проезд', 40),
#  ('Коптевская улица', 40),
#  ('Херсонская улица', 40),
#  ('улица Маршала Тухачевского', 40),
#  ('Звенигородское шоссе', 40),
#  ('улица Фабрициуса', 40),
#  ('улица Вилиса Лациса', 40),
#  ('Осенний бульвар', 40),
#  ('3-я Хорошёвская улица', 40),
#  ('Верейская улица', 40),
#  ('Большая Дорогомиловская улица', 40),
#  ('Юрловский проезд', 40),
#  ('3-й Дорожный проезд', 40),
#  ('улица Яблочкова', 40),
#  ('улица Милашенкова', 40),
#  ('Коломенская улица', 40),
#  ('улица Симоновский Вал', 40),
#  ('улица Радио', 40),
#  ('1-я Владимирская улица', 40),
#  ('Реутовская улица', 40),
#  ('Николоямская улица', 40),
#  ('площадь Киевского Вокзала', 40),
#  ('Веерная улица', 40),
#  ('Перовское шоссе', 40),
#  ('проспект 60-летия Октября', 40),
#  ('Мытная улица', 40),
#  ('Бакинская улица', 40),
#  ('улица Москворечье', 40),
#  ('улица Бехтерева', 40),
#  ('улица Серпуховский Вал', 40),
#  ('Марксистская улица', 40),
#  ('Мячковский бульвар', 40),
#  ('Лукинская улица', 40),
#  ('Старобитцевская улица', 40),
#  ('Братиславская улица', 40),
#  ('улица Бунинская Аллея', 40),
#  ('Советская улица', 40),
#  ('Заводская улица', 40),
#  ('Георгиевский проспект', 40),
#  ('улица Брусилова', 40),
#  ('Рязановское шоссе', 40),
#  ('2-й Лихачёвский переулок', 40),
#  ('Староникольская улица', 40),
#  ('Петрозаводская улица', 36),
#  ('Беломорская улица', 36),
#  ('улица Дыбенко', 36),
#  ('улица Красная Пресня', 36),
#  ('Карамышевская набережная', 36),
#  ('улица Мнёвники', 36),
#  ('Анадырский проезд', 36),
#  ('улица Малыгина', 36),
#  ('улица Алабяна', 36),
#  ('Снежная улица', 36),
#  ('Строгинский бульвар', 36),
#  ('улица Софьи Ковалевской', 36),
#  ('Берёзовая аллея', 36),
#  ('Сигнальный проезд', 36),
#  ('улица Пришвина', 36),
#  ('Осташковская улица', 36),
#  ('улица Красных Зорь', 36),
#  ('Бережковская набережная', 36),
#  ('Филёвский бульвар', 36),
#  ('улица 26-ти Бакинских Комиссаров', 36),
#  ('улица Римского-Корсакова', 36),
#  ('Булатниковская улица', 36),
#  ('Большая Серпуховская улица', 36),
#  ('Каланчёвская улица', 36),
#  ('Черноморский бульвар', 36),
#  ('Измайловский проспект', 36),
#  ('Коломенский проезд', 36),
#  ('Протопоповский переулок', 36),
#  ('Саянская улица', 36),
#  ('Кетчерская улица', 36),
#  ('Кусковская улица', 36),
#  ('улица Ивана Франко', 36),
#  ('Нежинская улица', 36),
#  ('улица Гарибальди', 36),
#  ('улица Архитектора Власова', 36),
#  ('улица Коштоянца', 36),
#  ('улица Академика Волгина', 36),
#  ('улица Новаторов', 36),
#  ('улица Маршала Шестопалова', 36),
#  ('улица Матросская Тишина', 36),
#  ('Совхозная улица', 36),
#  ('улица Шолохова', 36),
#  ('улица Скульптора Мухиной', 36),
#  ('улица 8 Марта', 36),
#  ('улица Маршала Полубоярова', 36),
#  ('улица Генерала Кузнецова', 36),
#  ('улица Верхняя Масловка', 36),
#  ('улица Горчакова', 36),
#  ('Перервинский бульвар', 36),
#  ('Воротынская улица', 36),
#  ('Солнечная улица', 36),
#  ('улица Андреевка', 36),
#  ('улица Авиаконструктора Сухого', 36),
#  ('улица Лётчика Спирина', 36),
#  ('Покровская улица', 36),
#  ('Лесная улица', 36),
#  ('Косинское шоссе', 36),
#  ('Рождественская улица', 36),
#  ('проспект 40 лет Октября', 36),
#  ('улица Генерала Донскова', 36),
#  ('Соболевский проезд', 36),
#  ('Петровско-Разумовский проезд', 32),
#  ('улица Бутырский Вал', 32),
#  ('Новослободская улица', 32),
#  ('Башиловская улица', 32),
#  ('улица Нижняя Масловка', 32),
#  ('улица Костякова', 32),
#  ('улица Константина Царёва', 32),
#  ('Новопесчаная улица', 32),
#  ('проезд Донелайтиса', 32),
#  ('Ельнинская улица', 32),
#  ('Богородское шоссе', 32),
#  ('Прибрежный проезд', 32),
#  ('Неманский проезд', 32),
#  ('Осенняя улица', 32),
#  ('улица Плещеева', 32),
#  ('Ярцевская улица', 32),
#  ('Давыдковская улица', 32),
#  ('Студёный проезд', 32),
#  ('улица Молодцова', 32),
#  ('Северный бульвар', 32),
#  ('Путевой проезд', 32),
#  ('улица Руставели', 32),
#  ('улица Пресненский Вал', 32),
#  ('улица Большая Полянка', 32),
#  ('Люсиновская улица', 32),
#  ('Олимпийский проспект', 32),
#  ('Малахитовая улица', 32),
#  ('Ереванская улица', 32),
#  ('2-й Грайвороновский проезд', 32),
#  ('улица Павла Корчагина', 32),
#  ('Щербаковская улица', 32),
#  ('Ткацкая улица', 32),
#  ('Бойцовая улица', 32),
#  ('улица Гастелло', 32),
#  ('Азовская улица', 32),
#  ('3-я Владимирская улица', 32),
#  ('Монтажная улица', 32),
#  ('улица Академика Павлова', 32),
#  ('улица Пречистенка', 32),
#  ('1-я Дубровская улица', 32),
#  ('улица Покровка', 32),
#  ('Матвеевская улица', 32),
#  ('улица Нижние Поля', 32),
#  ('Окская улица', 32),
#  ('улица Фёдора Полетаева', 32),
#  ('улица Маршала Голованова', 32),
#  ('Большая Грузинская улица', 32),
#  ('Верхняя Красносельская улица', 32),
#  ('Промышленная улица', 32),
#  ('Севанская улица', 32),
#  ('Загорьевский проезд', 32),
#  ('улица Маршала Захарова', 32),
#  ('Новоостаповская улица', 32),
#  ('Городецкая улица', 32),
#  ('Гурьевский проезд', 32),
#  ('улица Шаболовка', 32),
#  ('Большая Почтовая улица', 32),
#  ('улица Капотня', 32),
#  ('улица Цюрупы', 32),
#  ('улица Генерала Тюленева', 32),
#  ('Солнцевский проспект', 32),
#  ('улица Богданова', 32),
#  ('улица 50 лет Октября', 32),
#  ('улица Грина', 32),
#  ('Скобелевская улица', 32),
#  ('Приречная улица', 32),
#  ('улица Николая Старостина', 32),
#  ('улица Авиаконструктора Миля', 32),
#  ('Изюмская улица', 32),
#  ('улица Академика Семёнова', 32),
#  ('Нижняя Красносельская улица', 32),
#  ('Харьковский проезд', 32),
#  ('улица Руднёвка', 32),
#  ('Никольский проезд', 32),
#  ('Фирсановское шоссе', 32),
#  ('улица Дмитриевского', 32),
#  ('Муравская улица', 32),
#  ('улица Маршала Савицкого', 32),
#  ('Косинская улица', 32),
#  ('Внуковское шоссе', 32),
#  ('Большая Калитниковская улица', 32),
#  ('Локомотивный проезд', 28),
#  ('Планетная улица', 28),
#  ('Новомосковская улица', 28),
#  ('улица Лужники', 28),
#  ('улица Плющиха', 28),
#  ('Походный проезд', 28),
#  ('Карельский бульвар', 28),
#  ('Тушинская площадь', 28),
#  ('улица Космонавта Волкова', 28),
#  ('1-й Силикатный проезд', 28),
#  ('Беговая улица', 28),
#  ('улица Заморёнова', 28),
#  ('Белозерская улица', 28),
#  ('Костромская улица', 28),
#  ('улица Ивана Сусанина', 28),
#  ('улица Маршала Неделина', 28),
#  ('улица Конёнкова', 28),
#  ('Славянский бульвар', 28),
#  ('улица Грекова', 28),
#  ('улица Бестужевых', 28),
#  ('Большая Тульская улица', 28),
#  ('улица Докукина', 28),
#  ('проезд Русанова', 28),
#  ('Ферганский проезд', 28),
#  ('Ферганская улица', 28),
#  ('Грайвороновская улица', 28),
#  ('Большая Семёновская улица', 28),
#  ('Старая Басманная улица', 28),
#  ('Рабочая улица', 28),
#  ('улица Бирюсинка', 28),
#  ('Челябинская улица', 28),
#  ('Большой Купавенский проезд', 28),
#  ('улица Чечулина', 28),
#  ('Электролитный проезд', 28),
#  ('5-я Парковая улица', 28),
#  ('Красноармейская улица', 28),
#  ('Новая Басманная улица', 28),
#  ('шоссе Фрезер', 28),
#  ('Донецкая улица', 28),
#  ('улица Горбунова', 28),
#  ('улица Бутлерова', 28),
#  ('Михневская улица', 28),
#  ('Новохохловская улица', 28),
#  ('улица Винокурова', 28),
#  ('6-я Радиальная улица', 28),
#  ('2-й Боткинский проезд', 28),
#  ('Новоцарицынское шоссе', 28),
#  ('Тропарёвская улица', 28),
#  ('Рузская улица', 28),
#  ('Новороссийская улица', 28),
#  ('Куликовская улица', 28),
#  ('улица Федосьино', 28),
#  ('улица Проходчиков', 28),
#  ('Соколово-Мещерская улица', 28),
#  ('улица Логвиненко', 28),
#  ('Новокрюковская улица', 28),
#  ('Святоозерская улица', 28),
#  ('Машкинское шоссе', 28),
#  ('улица Красная Сосна', 28),
#  ('улица Академика Флёрова', 28),
#  ('проспект Защитников Москвы', 28),
#  ('Колхозная улица', 28),
#  ('4-я линия Хорошёвского Серебряного Бора', 28),
#  ('Краснопресненская набережная', 28),
#  ('улица Линии Октябрьской Железной Дороги', 24),
#  ('Нарвская улица', 24),
#  ('Автомоторная улица', 24),
#  ('Петровско-Разумовская аллея', 24),
#  ('Авангардная улица', 24),
#  ('Солнечногорская улица', 24),
#  ('улица Вучетича', 24),
#  ('Ижорская улица', 24),
#  ('улица Хамовнический Вал', 24),
#  ('Химкинский бульвар', 24),
#  ('улица Маршала Василевского', 24),
#  ('улица Генерала Глаголева', 24),
#  ('Ростокинский проезд', 24),
#  ('Лобненская улица', 24),
#  ('Строгинское шоссе', 24),
#  ('улица Гамалеи', 24),
#  ('4-я Магистральная улица', 24),
#  ('Мурановская улица', 24),
#  ('улица Говорова', 24),
#  ('Северодвинская улица', 24),
#  ('Тайнинская улица', 24),
#  ('Инженерная улица', 24),
#  ('Челюскинская улица', 24),
#  ('улица Академика Янгеля', 24),
#  ('Кольская улица', 24),
#  ('улица Советской Армии', 24),
#  ('Краснопролетарская улица', 24),
#  ('Долгоруковская улица', 24),
#  ('Стрельбищенский переулок', 24),
#  ('улица Измайловский Вал', 24),
#  ('Новорязанская улица', 24),
#  ('Битцевский проезд', 24),
#  ('улица Большие Каменщики', 24),
#  ('улица Газопровод', 24),
#  ('Костомаровский переулок', 24),
#  ('Уссурийская улица', 24),
#  ('Амурская улица', 24),
#  ('Красноярская улица', 24),
#  ('Мартеновская улица', 24),
#  ('улица Плющева', 24),
#  ('Вольная улица', 24),
#  ('16-я Парковая улица', 24),
#  ('Измайловское шоссе', 24),
#  ('аллея Жемчуговой', 24),
#  ('Тарусская улица', 24),
#  ('Таганская улица', 24),
#  ('улица Маршала Тимошенко', 24),
#  ('1-я улица Машиностроения', 24),
#  ('Гоголевский бульвар', 24),
#  ('Москворецкая набережная', 24),
#  ('Воронцовская улица', 24),
#  ('Очаковское шоссе', 24),
#  ('Староволынская улица', 24),
#  ('Тверской бульвар', 24),
#  ('улица Остоженка', 24),
#  ('Подольская улица', 24),
#  ('Саратовская улица', 24),
#  ('Семёновский проезд', 24),
#  ('Доброслободская улица', 24),
#  ('5-я Кабельная улица', 24),
#  ('Никитинская улица', 24),
#  ('3-й Крутицкий переулок', 24),
#  ('Садовая-Кудринская улица', 24),
#  ('улица Кравченко', 24),
#  ('Малая Грузинская улица', 24),
#  ('Иловайская улица', 24),
#  ('улица Медиков', 24),
#  ('3-й Павелецкий проезд', 24),
#  ('Дербеневская набережная', 24),
#  ('Кожевническая улица', 24),
#  ('Носовихинское шоссе', 24),
#  ('улица Довженко', 24),
#  ('улица Маршала Чуйкова', 24),
#  ('Нагорный проезд', 24),
#  ('Новокузнецкая улица', 24),
#  ('Пермская улица', 24),
#  ('улица Большая Ордынка', 24),
#  ('Чагинская улица', 24),
#  ('Соловьиный проезд', 24),
#  ('улица Академика Бакулева', 24),
#  ('Попутная улица', 24),
#  ('2-я Магистральная улица', 24),
#  ('Старокачаловская улица', 24),
#  ('Производственная улица', 24),
#  ('Чоботовская улица', 24),
#  ('Златоустовская улица', 24),
#  ('Международное шоссе', 24),
#  ('улица Академика Комарова', 24),
#  ('Вятская улица', 24),
#  ('Остафьевская улица', 24),
#  ('Заповедная улица', 24),
#  ('Юровская улица', 24),
#  ('Левобережная улица', 24),
#  ('улица Гризодубовой', 24),
#  ('улица Текстильщиков', 24),
#  ('улица Авиаконструктора Микояна', 24),
#  ('Солнечная аллея', 24),
#  ('Крюковская площадь', 24),
#  ('улица Гоголя', 24),
#  ('Алабушевская улица', 24),
#  ('Филаретовская улица', 24),
#  ('Островная улица', 24),
#  ('Сухонская улица', 24),
#  ('улица 40 лет Октября', 24),
#  ('Московская улица', 24),
#  ('Бачуринская улица', 24),
#  ('улица Золоторожский Вал', 24),
#  ('улица Пырьева', 24),
#  ('Госпитальная улица', 24),
#  ('улица Адмирала Макарова', 24),
#  ('Автомобильный проезд', 24),
#  ('Саввинская набережная', 24),
#  ('Новостроевская улица', 24),
#  ('Зимёнковская улица', 24),
#  ('Краснопрудная улица', 24),
#  ('улица Дубки', 24),
#  ('Погонный проезд', 24),
#  ('3-я Черепковская улица', 20),
#  ('улица Клары Цеткин', 20),
#  ('улица Академика Курчатова', 20),
#  ('улица Прянишникова', 20),
#  ('Краснополянская улица', 20),
#  ('улица Лавочкина', 20),
#  ('Звёздный бульвар', 20),
#  ('улица Маршала Федоренко', 20),
#  ('Станционная улица', 20),
#  ('Красностуденческий проезд', 20),
#  ('улица Расплетина', 20),
#  ('2-я Квесисская улица', 20),
#  ('4-й Вятский переулок', 20),
#  ('улица Рогова', 20),
#  ('улица Маршала Новикова', 20),
#  ('3-я Магистральная улица', 20),
#  ('улица Вильгельма Пика', 20),
#  ('Олонецкая улица', 20),
#  ('2-й Хорошёвский проезд', 20),
#  ('Лианозовский проезд', 20),
#  ('улица Артамонова', 20),
#  ('Сумская улица', 20),
#  ('Вологодский проезд', 20),
#  ('улица Большая Якиманка', 20),
#  ('улица Мусоргского', 20),
#  ('Мирской переулок', 20),
#  ('улица Фонвизина', 20),
#  ('Сумской проезд', 20),
#  ('Печорская улица', 20),
#  ('улица Добролюбова', 20),
#  ('улица Дурова', 20),
#  ('Ростокинская улица', 20),
#  ('улица Новинки', 20),
#  ('улица Преображенский Вал', 20),
#  ('Большая Оленья улица', 20),
#  ('Затонная улица', 20),
#  ('Котляковская улица', 20),
#  ('улица Сергия Радонежского', 20),
#  ('Камчатская улица', 20),
#  ('3-й Самотёчный переулок', 20),
#  ('2-й Иртышский проезд', 20),
#  ('Фрязевская улица', 20),
#  ('Электродная улица', 20),
#  ('улица Металлургов', 20),
#  ('улица Лазо', 20),
#  ('улица Ремизова', 20),
#  ('Бобруйская улица', 20),
#  ('Садовническая улица', 20),
#  ('улица Вострухина', 20),
#  ('7-я Парковая улица', 20),
#  ('Славянская площадь', 20),
#  ('улица Судакова', 20),
#  ('Тихорецкий бульвар', 20),
#  ('улица Рогожский Вал', 20),
#  ('Никулинская улица', 20),
#  ('проектируемый проезд № 1980', 20),
#  ('улица Марии Ульяновой', 20),
#  ('улица Лебедева', 20),
#  ('Сущёвская улица', 20),
#  ('Хордовый проезд', 20),
#  ('Паромная улица', 20),
#  ('Елецкая улица', 20),
#  ('Касимовская улица', 20),
#  ('Загорьевская улица', 20),
#  ('Ореховый проезд', 20),
#  ('Кустанайская улица', 20),
#  ('улица Строителей', 20),
#  ('Ухтомская улица', 20),
#  ('Пятницкая улица', 20),
#  ('4-й Загородный проезд', 20),
#  ('Малая Тульская улица', 20),
#  ('улица Инессы Арманд', 20),
#  ('Суворовская площадь', 20),
#  ('улица Покрышкина', 20),
#  ('Домостроительная улица', 20),
#  ('улица Щорса', 20),
#  ('Новопеределкинская улица', 20),
#  ('Новоорловская улица', 20),
#  ('Коктебельская улица', 20),
#  ('Луговой проезд', 20),
#  ('Красковская улица', 20),
#  ('Тихвинская улица', 20),
#  ('улица Саморы Машела', 20),
#  ('улица Талалихина', 20),
#  ('1-й Красногвардейский проезд', 20),
#  ('улица Михайловка', 20),
#  ('улица Конструктора Гуськова', 20),
#  ('улица Александровка', 20),
#  ('Малинская улица', 20),
#  ('улица Лётчицы Тарасовой', 20),
#  ('улица Рословка', 20),
#  ('Вернисажная улица', 20),
#  ('улица Маршала Прошлякова', 20),
#  ('Яковлевская улица', 20),
#  ('Клинская улица', 20),
#  ('Мещерский проспект', 20),
#  ('1-й Пенягинский проезд', 20),
#  ('улица Кибальчича', 20),
#  ('Раменский бульвар', 20),
#  ('Набережная Новикова-Прибоя', 20),
#  ('Улица Татьянин Парк', 20),
#  ('Цветной бульвар', 20),
#  ('2-я Бауманская улица', 20),
#  ('Коптевский бульвар', 16),
#  ('4-й Новомихалковский проезд', 16),
#  ('1-й Волоколамский проезд', 16),
#  ('улица Усиевича', 16),
#  ('Часовая улица', 16),
#  ('2-я Хуторская улица', 16),
#  ('улица Бусиновская Горка', 16),
#  ('Новинский бульвар', 16),
#  ('улица 1905 Года', 16),
#  ('Смоленский бульвар', 16),
#  ('Светлогорский проезд', 16),
#  ('улица Расковой', 16),
#  ('3-й Нижнелихоборский проезд', 16),
#  ('Старый Петровско-Разумовский проезд', 16),
#  ('Строительный проезд', 16),
#  ('Песчаная улица', 16),
#  ('Талдомская улица', 16),
#  ('Керамический проезд', 16),
#  ('улица Паршина', 16),
#  ('Одинцовская улица', 16),
#  ('Шелепихинское шоссе', 16),
#  ('Отрадная улица', 16),
#  ('Шелепихинская набережная', 16),
#  ('улица Фомичёвой', 16),
#  ('92-й километр Московской Кольцевой Автодороги', 16),
#  ('улица Толбухина', 16),
#  ('Илимская улица', 16),
#  ('Кременчугская улица', 16),
#  ('Воробьёвское шоссе', 16),
#  ('Новофилёвский проезд', 16),
#  ('Молдавская улица', 16),
#  ('улица Пестеля', 16),
#  ('Россошанский проезд', 16),
#  ('Федоскинская улица', 16),
#  ('Россошанская улица', 16),
#  ('улица Гончарова', 16),
#  ('улица Двинцев', 16),
#  ('улица Грузинский Вал', 16),
#  ('Новый Берингов проезд', 16),
#  ('Харьковская улица', 16),
#  ('Мясницкая улица', 16),
#  ('1-я улица Леонова', 16),
#  ('Большая Переяславская улица', 16),
#  ('улица Образцова', 16),
#  ('улица Новая Башиловка', 16),
#  ('Новоалексеевская улица', 16),
#  ('улица Олений Вал', 16),
#  ('Большая Ширяевская улица', 16),
#  ('Миллионная улица', 16),
#  ('Электрозаводский мост', 16),
#  ('Вельяминовская улица', 16),
#  ('Преображенская улица', 16),
#  ('Халтуринская улица', 16),
#  ('Просторная улица', 16),
#  ('улица Ленинская Слобода', 16),
#  ('Якорная улица', 16),
#  ('Потешная улица', 16),
#  ('улица Бориса Жигулёнкова', 16),
#  ('улица Шумкина', 16),
#  ('Новорогожская улица', 16),
#  ('Чусовская улица', 16),
#  ('Одесская улица', 16),
#  ('улица Старый Гай', 16),
#  ('Напольный проезд', 16),
#  ('Ясногорская улица', 16),
#  ('улица Айвазовского', 16),
#  ('улица Коновалова', 16),
#  ('Кузьминская улица', 16),
#  ('улица Василия Ботылёва', 16),
#  ('улица Зацепский Вал', 16),
#  ('улица Новый Арбат', 16),
#  ('улица Чугунные Ворота', 16),
#  ('Сормовская улица', 16),
#  ('Яузская улица', 16),
#  ('проезд Стройкомбината', 16),
#  ('Керченская улица', 16),
#  ('улица Шкулёва', 16),
#  ('Багратионовский проезд', 16),
#  ('Большая Андроньевская улица', 16),
#  ('Садовая-Спасская улица', 16),
#  ('Садовая-Самотёчная улица', 16),
#  ('Зубовский бульвар', 16),
#  ('улица Пржевальского', 16),
#  ('Новосущёвский переулок', 16),
#  ('улица Николая Химушина', 16),
#  ('Вильнюсская улица', 16),
#  ('Лубянская площадь', 16),
#  ('улица Академика Хохлова', 16),
#  ('улица Паустовского', 16),
#  ('Конюшковская улица', 16),
#  ('Холодильный переулок', 16),
#  ('улица Даниловский Вал', 16),
#  ('Ряжская улица', 16),
#  ('Новоспасский проезд', 16),
#  ('Луганская улица', 16),
#  ('улица Шверника', 16),
#  ('улица Гримау', 16),
#  ('Михневский проезд', 16),
#  ('Зеленодольская улица', 16),
#  ('Даниловская набережная', 16),
#  ('Юрьевский переулок', 16),
#  ('улица Орджоникидзе', 16),
#  ('Садовнический проезд', 16),
#  ('Устьинский проезд', 16),
#  ('Чистопрудный бульвар', 16),
#  ('улица Крупской', 16),
#  ('3-я Радиальная улица', 16),
#  ('34-й километр Московской Кольцевой Автодороги', 16),
#  ('32-й километр Московской Кольцевой Автодороги', 16),
#  ('проезд Одоевского', 16),
#  ('улица Раменки', 16),
#  ('улица Кедрова', 16),
#  ('7-я Кожуховская улица', 16),
#  ('Рочдельская улица', 16),
#  ('Инициативная улица', 16),
#  ('Елизаветинский переулок', 16),
#  ('3-й Сыромятнический переулок', 16),
#  ('1-я Магистральная улица', 16),
#  ('улица Комдива Орлова', 16),
#  ('площадь Соловецких Юнг', 16),
#  ('1-й Митинский переулок', 16),
#  ('улица Академика Глушко', 16),
#  ('улица Знаменские Садки', 16),
#  ('Волынская улица', 16),
#  ('9-я Чоботовская аллея', 16),
#  ('Саранская улица', 16),
#  ('Лермонтовский проспект', 16),
#  ('Хвалынский бульвар', 16),
#  ('бульвар Адмирала Ушакова', 16),
#  ('1-я Вольская улица', 16),
#  ('Родионовская улица', 16),
#  ('Дмитровский проезд', 16),
#  ('улица Академика Полякова', 16),
#  ('2-й Кожуховский проезд', 16),
#  ('Цимлянская улица', 16),
#  ('улица Саломеи Нерис', 16),
#  ('улица Маршала Воробьёва', 16),
#  ('Никулинский проезд', 16),
#  ('Комсомольская площадь', 16),
#  ('Середниковская улица', 16),
#  ('проезд № 474', 16),
#  ('Заводское шоссе', 16),
#  ('улица Панфилова', 16),
#  ('Новотушинский проезд', 16),
#  ('Новодачное шоссе', 16),
#  ('Клинский проезд', 16),
#  ('1-й Дачно-Мещерский проезд', 16),
#  ('проезд № 4922', 16),
#  ('Пяловская улица', 16),
#  ('Мурманский проезд', 16),
#  ('улица Липовый Парк', 16),
#  ('Лечебная улица', 16),
#  ('Луховицкая улица', 16),
#  ('улица Светланова', 16),
#  ('Энергетическая улица', 16),
#  ('2-й Красковский проезд', 16),
#  ('улица Речников', 16),
#  ('Ягодная улица', 16),
#  ('улица Бориса Пастернака', 16),
#  ('улица Зорге', 16),
#  ('улица Сретенка', 16),
#  ('площадь Тверская Застава', 16),
#  ('Садовая-Каретная улица', 16),
#  ('Смоленская набережная', 16),
#  ('улица Самуила Маршака', 16),
#  ('4-й Рощинский проезд', 16),
#  ('улица Госпитальный Вал', 16),
#  ('Новоданиловская набережная', 16),
#  ('Сосновая улица', 12),
#  ('Лужнецкая набережная', 12),
#  ('Смоленская-Сенная площадь', 12),
#  ('Рижская площадь', 12),
#  ('улица Саляма Адиля', 12),
#  ('Проспект Маршала Жукова', 12),
#  ('Песчаная площадь', 12),
#  ('Вишнёвая улица', 12),
#  ('площадь Академика Курчатова', 12),
#  ('проезд Соломенной Сторожки', 12),
#  ('улица Максимова', 12),
#  ('Ижорский проезд', 12),
#  ('улица Сергея Эйзенштейна', 12),
#  ('Отрадный проезд', 12),
#  ('Мелиховская улица', 12),
#  ('Псковская улица', 12),
#  ('Вяземская улица', 12),
#  ('улица Кубинка', 12),
#  ('Староможайское шоссе', 12),
#  ('улица Серафимовича', 12),
#  ('Истринская улица', 12),
#  ('Заревый проезд', 12),
#  ('Селезнёвская улица', 12),
#  ('улица Намёткина', 12),
#  ('Страстной бульвар', 12),
#  ('Семёновская площадь', 12),
#  ('Малая Черкизовская улица', 12),
#  ('Игральная улица', 12),
#  ('Велозаводская улица', 12),
#  ('улица Мастеркова', 12),
#  ('2-й Полевой переулок', 12),
#  ('2-й Котляковский переулок', 12),
#  ('Курганская улица', 12),
#  ('улица Достоевского', 12),
#  ('Иркутская улица', 12),
#  ('Снайперская улица', 12),
#  ('улица Уткина', 12),
#  ('улица Паперника', 12),
#  ('Полоцкая улица', 12),
#  ('Обводное шоссе', 12),
#  ('Космодамианская набережная', 12),
#  ('Таганская площадь', 12),
#  ('Верхняя Радищевская улица', 12),
#  ('Пречистенская набережная', 12),
#  ('улица Александра Солженицына', 12),
#  ('Жигулёвская улица', 12),
#  ('1-я Фрезерная улица', 12),
#  ('13-я Парковая улица', 12),
#  ('Абельмановская улица', 12),
#  ('Садовая-Черногрязская улица', 12),
#  ('Малая Сухаревская площадь', 12),
#  ('улица Крымский Вал', 12),
#  ('Валовая улица', 12),
#  ('Петровский бульвар', 12),
#  ('улица Академика Челомея', 12),
#  ('улица Кошкина', 12),
#  ('Павелецкая набережная', 12),
#  ('Менделеевская улица', 12),
#  ('улица Богатырский Мост', 12),
#  ('Никольско-Архангельский проезд', 12),
#  ('Покровский бульвар', 12),
#  ('6-й Лучевой просек', 12),
#  ('Большой Москворецкий мост', 12),
#  ('Малая Почтовая улица', 12),
#  ('проезд Олимпийской Деревни', 12),
#  ('улица Рокотова', 12),
#  ('48-й километр Московской Кольцевой Автодороги', 12),
#  ('Троекуровский проезд', 12),
#  ('бульвар Энтузиастов', 12),
#  ...]
